# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from app.prediction import predict_customer

# %%
sample = {

    "Recency":30,

    "Frequency":10,

    "Monetary":1500,

    "AverageOrderValue":150,

    "TotalQuantity":120,

    "UniqueProducts":30,

    "CustomerLifetime":300,

    "AveragePurchaseGap":20

}

prediction, probability = predict_customer(sample)

print(prediction)

print(probability)
# Out:
# 0
# 0.0011653269948707734
